# %% [markdown]
# # Redrob Candidate Discovery & Ranking Sandbox
#
# Welcome to the official sandbox run for **Team Antigravity AI**'s submission to the Intelligent Candidate Discovery & Ranking Challenge.
#
# This sandbox demonstrates our **Agentic RAG pipeline** running completely offline (without internet) on standard CPU compute.
#
# ### Instructions:
# 1. Run **Step 1** to clone our repository and load the codebase.
# 2. Run **Step 2** to generate a small sample of candidates (or drag and drop your own `test_candidates.jsonl` file into the file explorer on the left).
# 3. Run **Step 3** to execute our sandbox ranker: `rank.py`.
# 4. Run **Step 4** to view the final ranked CSV shortlist.

# %% [markdown]
# ### Step 1: Clone Repository & Setup Environment

# %%
# Clone the GitHub repository containing the pre-computed embedding database and scoring script
# !git clone https://github.com/Vabs1002/redrobai-hackathon-Protienbar.git
# %cd redrobai-hackathon-Protienbar

# %% [markdown]
# ### Step 2: Generate Candidate Sample Data
# We create a small self-contained sample candidates file to test reproducibility.

# %%
# Write a small sample candidate dataset (5 candidates including ML specialists and web developers)
sample_data = [
  # Candidate 1: Alice (Highly relevant AI Specialist)
  {
    "candidate_id": "CAND_0000031",
    "profile": {
      "anonymized_name": "Alice Developer",
      "headline": "Recommendation Systems Engineer | PyTorch, Vector Search",
      "summary": "ML Engineer with 6.0 years of experience building vector search databases.",
      "location": "Noida",
      "country": "India",
      "years_of_experience": 6.0,
      "current_title": "Recommendation Systems Engineer",
      "current_company": "Stripe"
    },
    "career_history": [
      {
        "company": "Stripe",
        "title": "Recommendation Systems Engineer",
        "start_date": "2023-01-01",
        "end_date": None,
        "duration_months": 41,
        "is_current": True,
        "industry": "Fintech",
        "description": "Built search recommendations using FAISS and Pinecone vector indexes."
      }
    ],
    "skills": [
      {"name": "Pinecone", "proficiency": "expert", "endorsements": 23, "duration_months": 36},
      {"name": "FAISS", "proficiency": "advanced", "endorsements": 12, "duration_months": 24},
      {"name": "Python", "proficiency": "expert", "endorsements": 30, "duration_months": 40}
    ],
    "redrob_signals": {
      "profile_completeness_score": 90.0,
      "signup_date": "2025-01-01",
      "last_active_date": "2026-06-10",
      "open_to_work_flag": True,
      "recruiter_response_rate": 0.91,
      "notice_period_days": 30
    }
  },
  # Candidate 2: Bob (Unrelated Frontend developer - Filtered out)
  {
    "candidate_id": "CAND_0000099",
    "profile": {
      "anonymized_name": "Bob Generalist",
      "headline": "Frontend Developer | React, Tailwind",
      "summary": "HTML/CSS frontend developer. Has no ML background.",
      "location": "Bangalore",
      "country": "India",
      "years_of_experience": 2.6,
      "current_title": "Frontend Developer",
      "current_company": "Freelance"
    },
    "career_history": [],
    "skills": [
      {"name": "React", "proficiency": "advanced", "endorsements": 5, "duration_months": 20}
    ],
    "redrob_signals": {
      "profile_completeness_score": 50.0,
      "signup_date": "2025-10-10",
      "last_active_date": "2026-06-15",
      "open_to_work_flag": True,
      "recruiter_response_rate": 0.81,
      "notice_period_days": 90
    }
  },
  # Candidate 3: Charlie (Honeypot with impossible dates - Filtered out)
  {
    "candidate_id": "CAND_0000055",
    "profile": {
      "anonymized_name": "Charlie Honeypot",
      "headline": "AI Engineer Expert",
      "summary": "AI Engineer with 8 years experience.",
      "location": "Pune",
      "country": "India",
      "years_of_experience": 8.0,
      "current_title": "AI Engineer",
      "current_company": "Startup"
    },
    "career_history": [
      {
        "company": "Startup",
        "title": "AI Engineer",
        "start_date": "2023-01-01",
        "end_date": "2024-01-01",
        "duration_months": 96,
        "is_current": False,
        "industry": "Software",
        "description": "Falsified timeline experience."
      }
    ],
    "skills": [
      {"name": "Pinecone", "proficiency": "expert", "endorsements": 10, "duration_months": 96}
    ],
    "redrob_signals": {
      "profile_completeness_score": 80.0,
      "signup_date": "2025-01-01",
      "last_active_date": "2026-06-15",
      "open_to_work_flag": True,
      "recruiter_response_rate": 0.85,
      "notice_period_days": 30
    }
  },
  # Candidate 4: Diana (Service company only history - Filtered out)
  {
    "candidate_id": "CAND_0000077",
    "profile": {
      "anonymized_name": "Diana Consultant",
      "headline": "Software Engineer | Python, Pinecone",
      "summary": "Software engineer with experience in database indexing.",
      "location": "Chennai",
      "country": "India",
      "years_of_experience": 5.0,
      "current_title": "Software Engineer",
      "current_company": "Infosys"
    },
    "career_history": [
      {
        "company": "Infosys",
        "title": "Software Engineer",
        "start_date": "2021-01-01",
        "end_date": None,
        "duration_months": 60,
        "is_current": True,
        "industry": "IT Services",
        "description": "Worked on database maintenance."
      }
    ],
    "skills": [
      {"name": "Pinecone", "proficiency": "intermediate", "endorsements": 5, "duration_months": 24},
      {"name": "Python", "proficiency": "advanced", "endorsements": 15, "duration_months": 48}
    ],
    "redrob_signals": {
      "profile_completeness_score": 85.0,
      "signup_date": "2024-01-01",
      "last_active_date": "2026-06-15",
      "open_to_work_flag": True,
      "recruiter_response_rate": 0.75,
      "notice_period_days": 60
    }
  },
  # Candidate 5: Ethan (Active AI Specialist in Pune)
  {
    "candidate_id": "CAND_0000088",
    "profile": {
      "anonymized_name": "Ethan Active",
      "headline": "AI Engineer | NLP and Vector Search",
      "summary": "Building search algorithms using sentence embeddings and Python.",
      "location": "Pune",
      "country": "India",
      "years_of_experience": 7.0,
      "current_title": "AI Engineer",
      "current_company": "Microsoft"
    },
    "career_history": [
      {
        "company": "Microsoft",
        "title": "AI Engineer",
        "start_date": "2022-01-01",
        "end_date": None,
        "duration_months": 53,
        "is_current": True,
        "industry": "Software",
        "description": "Implemented embeddings search and semantic indexes."
      }
    ],
    "skills": [
      {"name": "Embeddings", "proficiency": "expert", "endorsements": 25, "duration_months": 48},
      {"name": "Python", "proficiency": "expert", "endorsements": 30, "duration_months": 60},
      {"name": "Qdrant", "proficiency": "advanced", "endorsements": 10, "duration_months": 24}
    ],
    "redrob_signals": {
      "profile_completeness_score": 95.0,
      "signup_date": "2024-06-01",
      "last_active_date": "2026-06-16",
      "open_to_work_flag": True,
      "recruiter_response_rate": 0.95,
      "notice_period_days": 15
    }
  }
]

import json
with open('sandbox_candidates.jsonl', 'w', encoding='utf-8') as sf:
    for c in sample_data:
        sf.write(json.dumps(c) + '\n')
print("Created sandbox_candidates.jsonl successfully with 5 candidate profiles.")

# %% [markdown]
# ### Step 3: Run the Ranking Script
# Executes our sandbox ranker. This runs 100% offline using standard library parsing and rules.

# %%
# !python rank.py --candidates sandbox_candidates.jsonl --out sandbox_submission.csv

# %% [markdown]
# ### Step 4: Display Shortlist CSV
# Visualizes the ranked output format and recruiter reasonings.

# %%
import pandas as pd
df = pd.read_csv('sandbox_submission.csv')
df.head()
